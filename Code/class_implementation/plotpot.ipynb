# %%
#read potential.csv
# %matplotlib ipympl
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# read data from csv file
data = pd.read_csv('potentials.csv')
data.describe()
# Out:
#               Event          Time        V(t)_0        V(t)_1        V(t)_2  \
# count  17699.000000  1.769900e+04  17699.000000  17699.000000  17699.000000
# mean       6.385954  1.473883e-07      0.032283      0.026591      0.034806
# std        3.507113  8.795057e-08      0.030917      0.016443      0.030264
# min        1.000000  2.010320e-11     -0.075000      0.000000     -0.074999
# 25%        3.000000  6.932670e-08      0.020856      0.015141      0.023192
# 50%        6.000000  1.464270e-07      0.030198      0.022251      0.031995
# 75%       10.000000  2.256740e-07      0.040936      0.034102      0.042647
# max       12.000000  2.999520e-07      0.200000      0.108528      0.200000
#
#              V(t)_3        V(t)_4        V(t)_5        V(t)_6        V(t)_7  \
# count  17699.000000  17699.000000  17699.000000  17699.000000  17699.000000
# mean       0.034855      0.027708      0.032226      0.039466      0.025489
# ...

# %%
data['Time'][data['Event'] == 5].shape
# Out:
# (1254,)

# %%
fig, ax = plt.subplots(5, 2)
#fig size
fig.set_size_inches(10, 10)

# plot potential vs. time
for EV in range(1, 13):
    #plot in a matrix
    plt.subplot(6, 2, EV)
    #plt.scatter(data['Time'][data['Event'] == EV], data['V(t)_6'][data['Event'] == EV], c='b', marker='.',s=2)
    plt.plot(data['Time'][data['Event'] == EV], data['V(t)_6'][data['Event'] == EV], c='red', marker='None')
    plt.plot(data['Time'][data['Event'] == EV], data['V(t)_7'][data['Event'] == EV], c='orange', marker='None')
    plt.plot(data['Time'][data['Event'] == EV], data['V(t)_8'][data['Event'] == EV], c='yellow', marker='None')
    plt.plot(data['Time'][data['Event'] == EV], data['V(t)_9'][data['Event'] == EV], c='green', marker='None')
    plt.plot(data['Time'][data['Event'] == EV], data['V(t)_10'][data['Event'] == EV], c='blue', marker='None')
    plt.plot(data['Time'][data['Event'] == EV], data['V(t)_11'][data['Event'] == EV], c='purple', marker='None')
    plt.plot(data['Time'][data['Event'] == EV], data['V(t)_8'][data['Event'] == EV], c='black', marker='None')

    #plot trashhold
    plt.axhline(y=0.1, color='r', linestyle='-')
    plt.xlabel('Time (s)')
    plt.ylabel('Potential (V)')
    plt.title('Event ' + str(EV))
plt.tight_layout()
plt.savefig("V6.pdf")
plt.show()
# Out:
# /tmp/ipykernel_1937/871199645.py:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(6, 2, EV)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data.hist("Time");
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
