# %%
#read potential.csv

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# read data from csv file
data = pd.read_csv('potentials.csv')
data.describe()
# Out:
#              Event          Time       V(t)_0       V(t)_1       V(t)_2  \
# count  2075.000000  2.075000e+03  2075.000000  2075.000000  2075.000000
# mean      5.863614  7.980635e-08     0.009344     0.010842     0.025356
# std       2.790361  8.226171e-08     0.018537     0.019023     0.039561
# min       1.000000  0.000000e+00    -0.074975    -0.074624    -0.075873
# 25%       3.000000  2.073920e-43     0.000000     0.000000     0.000000
# 50%       6.000000  5.178850e-08     0.005496     0.008806     0.020711
# 75%       8.000000  1.547760e-07     0.018881     0.021298     0.040983
# max      10.000000  2.498230e-07     0.157918     0.157918     0.200000
#
#             V(t)_3       V(t)_4       V(t)_5       V(t)_6       V(t)_7  \
# count  2075.000000  2075.000000  2075.000000  2075.000000  2075.000000
# mean      0.010812     0.061127     0.012962     0.008473     0.006176
# std       0.019460     0.084817     0.019911     0.018593     0.015551
# min      -0.074412    -0.074358    -0.074358    -0.074780    -0.074580
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.007753     0.000000     0.011961     0.003945     0.006132
# 75%       0.020747     0.200000     0.026105     0.018026     0.014541
# max       0.157918     0.200000     0.157918     0.157918     0.157918
#
#             V(t)_8       V(t)_9      V(t)_10      V(t)_11
# count  2075.000000  2075.000000  2075.000000  2075.000000
# mean      0.009296     0.010492     0.030376     0.005149
# std       0.018616     0.018493     0.043854     0.015871
# min      -0.074789    -0.074594    -0.071486    -0.074810
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%       0.005713     0.008850     0.024650     0.003134
# 75%       0.018511     0.021508     0.045356     0.011901
# max       0.157918     0.157918     0.200000     0.157918

# %%
data['Time'][data['Event'] == 5].shape
# Out:
# (221,)

# %%
fig, ax = plt.subplots(5, 2)
#fig size
fig.set_size_inches(10, 10)

# plot potential vs. time
for EV in range(1, 11):
    #plot in a matrix
    plt.subplot(5, 2, EV)
    plt.scatter(data['Time'][data['Event'] == EV], data['V(t)_2'][data['Event'] == EV], c='b', marker='.',s=2)
    # plt.plot(data['Time'][data['Event'] == EV], data['V(t)_3'][data['Event'] == EV], c='b', marker='.')

    #plot trashhold
    plt.axhline(y=0.1, color='r', linestyle='-')
    plt.xlabel('Time (s)')
    plt.ylabel('Potential (V)')
    plt.title('Event ' + str(EV))
plt.tight_layout()
plt.show()

# %%
data.hist("Time");
